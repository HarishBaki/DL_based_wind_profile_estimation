# %%
# %%time
import xarray as xr
import numpy as np
import joblib as jb
import time
import pandas as pd
import os, glob
# Out:
# CPU times: user 235 ms, sys: 60.1 ms, total: 295 ms
# Wall time: 294 ms

# %%
os.chdir('/g/data/xv83/jp6794/NeurIPS23/ML_stuff/Harish')

# %%
import dask.distributed
import os
import tempfile

_dask_client = None
_tmpdir = None
def Client(threads=1, malloc_trim_threshold=None):
    global _dask_client, _tmpdir

    env = {}

    if malloc_trim_threshold is not None:
        env["MALLOC_TRIM_THRESHOLD_"] = str(
            dask.utils.parse_bytes(malloc_trim_threshold)
        )

    if _dask_client is None:
        _tmpdir = tempfile.TemporaryDirectory("dask-worker-space")
        workers = int(os.environ["PBS_NCPUS"]) // threads
        _dask_client = dask.distributed.Client(
            n_workers=workers,
            threads_per_worker=threads,
            memory_limit=int(os.environ["PBS_VMEM"]) / (workers),
            local_directory=_tmpdir.name,
            env=env,
            )
    return _dask_client
Client()
# Out:
# <Client: 'tcp://127.0.0.1:42815' processes=28 threads=28, memory=252.00 GiB>

# %%
# Function to find the closest index in a 1D array
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx
def era5_sfc_hourly(year,par,par_name,target_lat,target_lon):
    folder = "/g/data/rt52/era5/single-levels/reanalysis"
    file = f'{folder}/{par}/{year}/{par}_era5_oper_sfc_{year}'+'*.nc'
    hr_data = xr.open_mfdataset(file,
                                chunks={'lat': -1, 'lon': -1, 'time': 24}, 
                                parallel=True)
    latitude = hr_data.latitude
    longitude = hr_data.longitude
    lat_idx = find_nearest(latitude, target_lat)
    lon_idx = find_nearest(longitude, target_lon)
    hr_cor_data = hr_data[par_name].sel(latitude=latitude[lat_idx], 
                      longitude=longitude[lon_idx], method='nearest')
    return hr_cor_data

def era5_pres_hourly(year, par, level, target_lat,target_lon):
    folder = "/g/data/rt52/era5/pressure-levels/reanalysis/"
    file = folder+par+'/'+str(year)+'/'+par+'_era5_oper_pl_'+str(year)+'*.nc'
    hr_data = xr.open_mfdataset(file,
                                chunks={'level': 1,'lat': -1, 'lon': -1, 'time': 24}, 
                                parallel=True)
    latitude = hr_data.latitude
    longitude = hr_data.longitude
    lat_idx = find_nearest(latitude, target_lat)
    lon_idx = find_nearest(longitude, target_lon)
    hr_cor_data = hr_data[par].sel(level=level).sel(latitude=latitude[lat_idx], 
                      longitude=longitude[lon_idx], method='nearest').drop('level')
    hr_cor_data = hr_cor_data.rename(f'{par}_{level}')
    return hr_cor_data

# %% [markdown]
# ### Extracting surface variables

# %%
# %%time
era5_dir = '/g/data/rt52/era5/single-levels/reanalysis'
pars = ['10u', '10v','100u', '100v','zust','i10fg',
       '2t','skt','stl1','2d','msl','blh','cbh',
       'ishf','ie','tcc','lcc','cape','cin','bld']
par_names = ['u10', 'v10', 'u100', 'v100','zust','i10fg',
            't2m','skt','stl1','d2m','msl','blh','cbh',
            'ishf','ie','tcc','lcc','cape','cin','bld']
lats=[54.0143,
        51.97,
        56.44050,
        51.706898,
        51.6463,
        51.9171,
        51.9990,
        52.306583,
        53.71250,
        54,
        54.177256]
lons=[6.58385,
        4.93,
        8.15080,
        3.034618,
        2.95141,
        3.6670,
        3.2760,
        4.008972,
        7.1522,
        6.623333,
        7.891971
        ]
data_dir = 'data'
for par,par_name in zip(pars,par_names):
    # create a folder with name par inside data_dir
    par_dir = f'{data_dir}/{par}'
    os.makedirs(par_dir, exist_ok=True)
    # --- extract data at each year ---#
    for year in np.arange(2000,2018+1):
        datasets = []
        for loc in range(len(lats)):
            ds = era5_sfc_hourly(year, par, par_name, lats[loc], lons[loc])
            datasets.append(ds.compute())
            del(ds)
        # Concatenate datasets along a new dimension ('location')
        combined_dataset = xr.concat(datasets, dim='location')
        combined_dataset['year'] = year
        file_path = f'{par_dir}/{year}.nc'
        if os.path.exists(file_path):
            os.remove(file_path)
        combined_dataset.to_netcdf(file_path)
        del(combined_dataset)
        print(par,year)
    # --- combining all years data ---#
    ds = xr.open_mfdataset(f'{data_dir}/{par}/*.nc',chunks={'lat': -1, 'lon': -1, 'time': -1}, 
                                parallel=True)
    file_path = f'{data_dir}/{par}.nc'
    if os.path.exists(file_path):
        os.remove(file_path)
    ds.to_netcdf(file_path)
    print(par)

# %% [markdown]
# ### Extracting pressure level variables

# %%
data_dir = 'data'
lvls = [975,950]
pars = ['u','v','t']
lats=[54.0143,
        51.97,
        56.44050,
        51.706898,
        51.6463,
        51.9171,
        51.9990,
        52.306583,
        53.71250,
        54,
        54.177256]
lons=[6.58385,
        4.93,
        8.15080,
        3.034618,
        2.95141,
        3.6670,
        3.2760,
        4.008972,
        7.1522,
        6.623333,
        7.891971
        ]
for par in pars:
    for level in lvls:
        # create a folder with name par and level inside data_dir
        par_dir = f'{data_dir}/{par}_{level}'
        os.makedirs(par_dir, exist_ok=True)
        # --- extract data at each year ---#
        for year in np.arange(2000,2018+1):
            datasets = []
            for loc in range(len(lats)):
                ds = era5_pres_hourly(year, par,level, lats[loc], lons[loc])
                datasets.append(ds.compute())
                del(ds)
            # Concatenate datasets along a new dimension ('location')
            combined_dataset = xr.concat(datasets, dim='location')
            combined_dataset['year'] = year
            file_path = f'{par_dir}/{year}.nc'
            if os.path.exists(file_path):
                os.remove(file_path)
            combined_dataset.to_netcdf(file_path)
            del(combined_dataset)
            print(par,level,year)
        # --- combining all years data ---#
        ds = xr.open_mfdataset(f'{par_dir}/*.nc',chunks={'lat': -1, 'lon': -1, 'time': -1}, 
                                    parallel=True)
        file_path = f'{data_dir}/{par}_{level}.nc'
        if os.path.exists(file_path):
            os.remove(file_path)
        ds.to_netcdf(file_path)
        print(par)

# %% [markdown]
# ## Combining all variables into one file

# %%
client.close()
cluster.close()

# %%
import dask.distributed as dd
import dask
import dask.array as da
# Create a Dask cluster
print("Starting parallel computing...")
cluster = dd.LocalCluster(n_workers=16, dashboard_address=':22722')

# Connect to the cluster
client = dd.Client(cluster)
client
# Out:
# Starting parallel computing...
# <Client: 'tcp://127.0.0.1:34153' processes=16 threads=128, memory=503.49 GiB>
# 2025-03-10 18:57:37,574 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39021' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-latitude-4d73159fda913f14a96a30a4c82c00dc'} (stimulus_id='handle-worker-cleanup-1741647457.5747197')
# 2025-03-10 18:57:37,576 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35943' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-year-e9339f70f925259d3ca6ae556b598f72'} (stimulus_id='handle-worker-cleanup-1741647457.5765789')
# 2025-03-10 18:57:37,577 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36605' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-u10-7958aa08081845da4478a41d72be6eb7'} (stimulus_id='handle-worker-cleanup-1741647457.577861')
# 2025-03-10 18:57:37,579 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36721' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-longitude-4d73159fda913f14a96a30a4c82c00dc'} (stimulus_id='handle-worker-cleanup-1741647457.579577')
# 2025-03-10 18:57:37,601 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41211'.
# 2025-03-10 18:57:37,602 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41111'.
# 2025-03-10 18:57:37,603 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39021'.
# 2025-03-10 18:57:37,604 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:42803'.
# 2025-03-10 18:57:37,605 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39957'.
# 2025-03-10 18:57:37,605 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46347'.
# 2025-03-10 18:57:37,606 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36721'.
# 2025-03-10 18:57:37,606 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46611'.
# 2025-03-10 18:57:37,607 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44887'.
# 2025-03-10 18:57:37,607 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:41137'.
# 2025-03-10 18:57:37,608 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:44963'.
# 2025-03-10 18:57:37,608 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:36605'.
# 2025-03-10 18:57:37,609 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:46297'.
# 2025-03-10 18:57:37,609 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:35943'.
# 2025-03-10 18:57:37,610 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39305'.
# 2025-03-10 18:57:37,610 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:43135'.

# %% [markdown]
# ## Raw variables

# %%
combined_dataset = xr.Dataset()

pars = ['10u', '10v','100u', '100v','zust','i10fg','u_975','v_975','u_950','v_950',
       '2t','skt','stl1','2d','msl','blh','cbh',
       'ishf','ie','tcc','lcc','cape','cin','bld','t_975','t_950']
par_names = ['u10', 'v10', 'u100', 'v100','zust','i10fg','u_975','v_975','u_950','v_950',
            't2m','skt','stl1','d2m','msl','blh','cbh',
            'ishf','ie','tcc','lcc','cape','cin','bld','t_975','t_950']

for par in pars:
    file_path = f'../data/ERA5_complete/{par}.nc'
    ds = xr.open_dataset(file_path,chunks={'lat': -1, 'lon': -1, 'time': -1}).load()
    combined_dataset = xr.merge([combined_dataset, ds])
    print(par)
# Out:
# 10u
# 10v
# 100u
# 100v
# zust
# i10fg
# u_975
# v_975
# u_950
# v_950
# 2t
# skt
# stl1
# 2d
# msl
# blh
# cbh
# ishf
# ie
# tcc
# lcc
# cape
# cin
# bld
# t_975
# t_950

# %% [markdown]
# ## Derived variables

# %%
def compute_wind_speed(dataset,par_name1,par_name2, par_name): 
    ds = (dataset[par_name1]**2+dataset[par_name2]**2)**0.5
    ds = ds.rename(par_name)
    return ds
def compute_alpha(dataset, par_name1,par_name2, par_name):
    ds = np.log(dataset[par_name2]/dataset[par_name1])/np.log(100/10)
    ds = ds.rename(par_name)
    return ds
def compute_gradient(dataset, par_name1,par_name2, par_name):
    ds = dataset[par_name2]-dataset[par_name1]
    ds = ds.rename(par_name)
    return ds

# %%
# --- 10m wind ---#
ds = compute_wind_speed(combined_dataset,'u10','v10', '10ws')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 100m wind ---#
ds = compute_wind_speed(combined_dataset,'u100','v100', '100ws')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 975 wind ---#
ds = compute_wind_speed(combined_dataset,'u_975','v_975', '975ws')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 950 wind ---#
ds = compute_wind_speed(combined_dataset,'u_950','v_950', '950ws')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 100 alpha ---#
ds = compute_alpha(combined_dataset,'10ws','100ws','100alpha')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 975 wind gradient ---#
ds = compute_gradient(combined_dataset,'100ws','975ws','975wsgrad')
combined_dataset = xr.merge([combined_dataset, ds])

# --- 950 wind gradient ---#
ds = compute_gradient(combined_dataset,'975ws','950ws','950wsgrad')
combined_dataset = xr.merge([combined_dataset, ds]) 

# --- 2m temperature gradient ---#
ds = compute_gradient(combined_dataset,'skt','t2m','2mtempgrad')
combined_dataset = xr.merge([combined_dataset, ds]) 

# --- skin temperature gradient ---#
ds = compute_gradient(combined_dataset,'stl1','skt','sktempgrad')
combined_dataset = xr.merge([combined_dataset, ds]) 

# --- Temperature dewpoint spread ---#
ds = compute_gradient(combined_dataset,'d2m','t2m','dewtempsprd')
combined_dataset = xr.merge([combined_dataset, ds]) 
    
# --- 950 temperature gradient ---#
ds = compute_gradient(combined_dataset,'t_975','t_950','950tempgrad')
combined_dataset = xr.merge([combined_dataset, ds]) 

# --- 975 temperature gradient ---#
ds = compute_gradient(combined_dataset,'t2m','t_975','975tempgrad')
combined_dataset = xr.merge([combined_dataset, ds])

# %%
HR =  pd.to_datetime(combined_dataset.time).hour
# --- sin converted hour ---#
ds = xr.DataArray(np.sin(2 * np.pi / 24 * HR), coords=[combined_dataset.time], dims=['time'], name='sinHR')
combined_dataset = xr.merge([combined_dataset, ds])

# --- cosine converted hour ---#
ds = xr.DataArray(np.cos(2 * np.pi / 24 * HR), coords=[combined_dataset.time], dims=['time'], name='cosHR')
combined_dataset = xr.merge([combined_dataset, ds])

JDAY  = pd.to_datetime(combined_dataset.time).dayofyear
# --- sin converted day ---#
ds = xr.DataArray(np.sin(2 * np.pi / 366 * JDAY), coords=[combined_dataset.time], dims=['time'], name='sinJDAY')
combined_dataset = xr.merge([combined_dataset, ds])

# --- cosine converted day ---#
ds = xr.DataArray(np.cos(2 * np.pi / 366 * JDAY), coords=[combined_dataset.time], dims=['time'], name='cosJDAY')
combined_dataset = xr.merge([combined_dataset, ds])

# %%
def compute_temp_shift(dataset, par_name, delta_t):
    ds = dataset[par_name]-dataset[par_name].shift(time=delta_t)
    ds = ds.rename(f'{par_name}_delta{delta_t}')
    return ds

# %%
pars = ['10ws','100ws','975ws','950ws']
for par in pars:
    for delta_t in range(1,7):
        ds = compute_temp_shift(combined_dataset,par,delta_t)
        combined_dataset = xr.merge([combined_dataset, ds])
        print(ds.name)
# Out:
# 10ws_delta1
# 10ws_delta2
# 10ws_delta3
# 10ws_delta4
# 10ws_delta5
# 10ws_delta6
# 100ws_delta1
# 100ws_delta2
# 100ws_delta3
# 100ws_delta4
# 100ws_delta5
# 100ws_delta6
# 975ws_delta1
# 975ws_delta2
# 975ws_delta3
# 975ws_delta4
# 975ws_delta5
# 975ws_delta6
# 950ws_delta1
# 950ws_delta2
# 950ws_delta3
# 950ws_delta4
# 950ws_delta5
# 950ws_delta6

# %% [markdown]
# ## Adding central moments

# %%
#combined_dataset = xr.open_dataset('../data/ERA5.nc')
par_names = ['u10', 'v10', 'u100', 'v100','u_975','v_975','u_950','v_950']

for par in par_names:
    y = combined_dataset[par]
    rolling = y.rolling(time=12,center=False)
    y_mean = rolling.mean()
    y_std = rolling.std()
    y_skew = ((rolling.construct('window_dim') - rolling.reduce(np.mean))**3).mean('window_dim')
    y_kurt = ((rolling.construct('window_dim') - rolling.reduce(np.mean))**4).mean('window_dim')

    combined_dataset[f'{par}_mean'] = y_mean
    combined_dataset[f'{par}_std'] = y_std
    combined_dataset[f'{par}_skew'] = y_skew
    combined_dataset[f'{par}_kurt'] = y_kurt
    print(par)
# Out:
# u10
# v10
# u100
# v100
# u_975
# v_975
# u_950
# v_950

# %%
# === save file ===#
file_path = f'../data/ERA5.nc'
if os.path.exists(file_path):
    os.remove(file_path)
combined_dataset.to_netcdf(file_path)
